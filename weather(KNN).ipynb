# %%
cd C:\Users\HP\OneDrive\Documents
# Out:
# C:\Users\HP\OneDrive\Documents

# %%
pwd
# Out:
# 'C:\\Users\\HP\\OneDrive\\Documents'

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("weather.csv",parse_dates = True, index_col = 0)
data
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2008-02-01      8.0     24.3       0.0          3.4       6.3          NW
# 2008-02-02     14.0     26.9       3.6          4.4       9.7         ENE
# 2008-02-03     13.7     23.4       3.6          5.8       3.3          NW
# 2008-02-04     13.3     15.5      39.8          7.2       9.1          NW
# 2008-02-05      7.6     16.1       2.8          5.6      10.6         SSE
# ...             ...      ...       ...          ...       ...         ...
# 2009-01-27      9.0     30.7       0.0          7.6      12.1         NNW
# 2009-01-28      7.1     28.4       0.0         11.6      12.7           N
# 2009-01-29     12.5     19.9       0.0          8.4       5.3         ESE
# 2009-01-30     12.5     26.9       0.0          5.0       7.1          NW
# 2009-01-31     12.3     30.2       0.0          6.0      12.6          NW
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# ...

# %%
data.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2008-02-01      8.0     24.3       0.0          3.4       6.3          NW
# 2008-02-02     14.0     26.9       3.6          4.4       9.7         ENE
# 2008-02-03     13.7     23.4       3.6          5.8       3.3          NW
# 2008-02-04     13.3     15.5      39.8          7.2       9.1          NW
# 2008-02-05      7.6     16.1       2.8          5.6      10.6         SSE
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2008-02-01           30.0         SW         NW           6.0  ...
# 2008-02-02           39.0          E          W           4.0  ...
# 2008-02-03           85.0          N        NNE           6.0  ...
# 2008-02-04           54.0        WNW          W          30.0  ...
# 2008-02-05           50.0        SSE        ESE          20.0  ...
#
# ...

# %%
data.tail()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2009-01-27      9.0     30.7       0.0          7.6      12.1         NNW
# 2009-01-28      7.1     28.4       0.0         11.6      12.7           N
# 2009-01-29     12.5     19.9       0.0          8.4       5.3         ESE
# 2009-01-30     12.5     26.9       0.0          5.0       7.1          NW
# 2009-01-31     12.3     30.2       0.0          6.0      12.6          NW
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2009-01-27           76.0        SSE         NW           7.0  ...
# 2009-01-28           48.0        NNW        NNW           2.0  ...
# 2009-01-29           43.0        ENE        ENE          11.0  ...
# 2009-01-30           46.0        SSW        WNW           6.0  ...
# 2009-01-31           78.0         NW        WNW          31.0  ...
#
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2008-02-01', '2008-02-02', '2008-02-03', '2008-02-04',
#                '2008-02-05', '2008-02-06', '2008-02-07', '2008-02-08',
#                '2008-02-09', '2008-02-10',
#                ...
#                '2009-01-22', '2009-01-23', '2009-01-24', '2009-01-25',
#                '2009-01-26', '2009-01-27', '2009-01-28', '2009-01-29',
#                '2009-01-30', '2009-01-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2008-02-01 to 2009-01-31
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
dataset = data[['Pressure3pm','Cloud9am','Temp3pm','RainToday']]
dataset.head()
# Out:
#             Pressure3pm  Cloud9am  Temp3pm RainToday
# Date
# 2008-02-01       1015.0         7     23.6        No
# 2008-02-02       1008.4         5     25.7       Yes
# 2008-02-03       1007.2         8     20.2       Yes
# 2008-02-04       1007.0         2     14.1       Yes
# 2008-02-05       1018.5         7     15.4       Yes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax = plt.subplots()
dataset[dataset['RainToday']=='No'].plot.scatter(x='Cloud9am',y='Temp3pm',c='g',alpha = 0.60,ax=ax)
dataset[dataset['RainToday']=='Yes'].plot.scatter(x='Cloud9am',y='Temp3pm',c='y',alpha = 0.60,ax=ax)
# Out:
# <Axes: xlabel='Cloud9am', ylabel='Temp3pm'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dataset.isnull().sum()
# Out:
# Pressure3pm    0
# Cloud9am       0
# Temp3pm        0
# RainToday      0
# dtype: int64

# %%
x = dataset[['Cloud9am','Temp3pm']]
y = dataset['RainToday']
y = np.array([0 if value == 'No' else 1 for value in y])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
print("shape x_train :",x_train.shape)
print("shape y_train :",y_train.shape)
print("shape x_test :",x_test.shape)
print("shape y_test :",y_test.shape)
# Out:
# shape x_train : (274, 2)
# shape y_train : (274,)
# shape x_test : (92, 2)
# shape y_test : (92,)

# %%
neigh = KNeighborsClassifier()
neigh.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = neigh.predict(x_test)
y_pred
accuracy_score(y_test,y_pred)
# Out:
# 0.7934782608695652

# %%
print("test_score of the model : ",neigh.score(x_test,y_test))
print("train_score of the model : ",neigh.score(x_train,y_train))
# Out:
# test_score of the model :  0.7934782608695652
# train_score of the model :  0.8394160583941606

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred)
print(confusion_matrix)
# Out:
# [[70  4]
#  [15  3]]

# %% [markdown]
# The result telling us that we have 73 correct predictions and 19 incorrect predictions.
#
# # TP,FP
# # FN,TN

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88        74
#            1       0.43      0.17      0.24        18
#
#     accuracy                           0.79        92
#    macro avg       0.63      0.56      0.56        92
# weighted avg       0.75      0.79      0.76        92

# %% [markdown]
# # Precision = TP/TP+FP,
#
# # Recall = TP/TP+FN,
#
# # Accuracy = TP+TN/TP+TN+FP+FN,
#
# # f1-score = (2xPrecisionxRecall)/(Precision+Recall) =TP/[TP+1/2(FP+FN)]

# %%
dataset = data[['Rainfall','Evaporation','RainToday']]
dataset.head()
# Out:
#             Rainfall  Evaporation RainToday
# Date
# 2008-02-01       0.0          3.4        No
# 2008-02-02       3.6          4.4       Yes
# 2008-02-03       3.6          5.8       Yes
# 2008-02-04      39.8          7.2       Yes
# 2008-02-05       2.8          5.6       Yes

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dataset.isnull().sum()
# Out:
# Rainfall       0
# Evaporation    0
# RainToday      0
# dtype: int64

# %%
x = dataset[['Rainfall','Evaporation']]
y = dataset['RainToday']
y = np.array([0 if value == 'No' else 1 for value in y])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
print("shape x_train :",x_train.shape)
print("shape y_train :",y_train.shape)
print("shape x_test :",x_test.shape)
print("shape y_test :",y_test.shape)
# Out:
# shape x_train : (274, 2)
# shape y_train : (274,)
# shape x_test : (92, 2)
# shape y_test : (92,)

# %%
neigh = KNeighborsClassifier()
neigh.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = neigh.predict(x_test)
y_pred
accuracy_score(y_test,y_pred)
# Out:
# 0.9782608695652174

# %%
print("test_score of the model : ",neigh.score(x_test,y_test))
print("train_score of the model : ",neigh.score(x_train,y_train))
# Out:
# test_score of the model :  0.9782608695652174
# train_score of the model :  0.9854014598540146

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred)
print(confusion_matrix)
# Out:
# [[74  0]
#  [ 2 16]]

# %%
dataset = data[['MinTemp','MaxTemp','RainTomorrow']]
dataset.head()
# Out:
#             MinTemp  MaxTemp RainTomorrow
# Date
# 2008-02-01      8.0     24.3          Yes
# 2008-02-02     14.0     26.9          Yes
# 2008-02-03     13.7     23.4          Yes
# 2008-02-04     13.3     15.5          Yes
# 2008-02-05      7.6     16.1           No

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dataset.isnull().sum()
# Out:
# MinTemp         0
# MaxTemp         0
# RainTomorrow    0
# dtype: int64

# %%
x = dataset[['MinTemp','MaxTemp']]
y = dataset['RainTomorrow']
y = np.array([0 if value == 'No' else 1 for value in y])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
print("shape x_train :",x_train.shape)
print("shape y_train :",y_train.shape)
print("shape x_test :",x_test.shape)
print("shape y_test :",y_test.shape)
# Out:
# shape x_train : (274, 2)
# shape y_train : (274,)
# shape x_test : (92, 2)
# shape y_test : (92,)

# %%
neigh = KNeighborsClassifier()
neigh.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = neigh.predict(x_test)
y_pred
accuracy_score(y_test,y_pred)
# Out:
# 0.8260869565217391

# %%
print("test_score of the model : ",neigh.score(x_test,y_test))
print("train_score of the model : ",neigh.score(x_train,y_train))
# Out:
# test_score of the model :  0.8260869565217391
# train_score of the model :  0.8467153284671532

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred)
print(confusion_matrix)
# Out:
# [[72  3]
#  [13  4]]

# %%
dataset = data[['Evaporation','Sunshine','RainToday']]
dataset.head()
# Out:
#             Evaporation  Sunshine RainToday
# Date
# 2008-02-01          3.4       6.3        No
# 2008-02-02          4.4       9.7       Yes
# 2008-02-03          5.8       3.3       Yes
# 2008-02-04          7.2       9.1       Yes
# 2008-02-05          5.6      10.6       Yes

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dataset.isnull().sum()
# Out:
# Evaporation    0
# Sunshine       3
# RainToday      0
# dtype: int64

# %%
x = dataset[['Evaporation','Sunshine']]
y = dataset['RainToday']
y = np.array([0 if value == 'No' else 1 for value in y])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
print("shape x_train :",x_train.shape)
print("shape y_train :",y_train.shape)
print("shape x_test :",x_test.shape)
print("shape y_test :",y_test.shape)
# Out:
# shape x_train : (274, 2)
# shape y_train : (274,)
# shape x_test : (92, 2)
# shape y_test : (92,)
